# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav873/Gen--AI/blob/main/prompting/prompting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A prompt is the input or instruction given to an AI model to tell it what task to perform and what kind of response is expected.
#
# A prompt can contain:
#
# Instructions
# Questions
# Context
# Examples
# Constraints
# Output format
#
# Instruction:
# Summarize the following customer feedback.
#
# Question:
# What are the main issues reported by customers?
#
# Context:
# The feedback is collected from users of an online food delivery app.
#
# Examples:
# Input: "Delivery was late but food quality was good."
# Output: "Delivery Issue"
#
# Constraints:
# - Use only the provided feedback
# - Do not add assumptions
# - Keep the answer under 100 words
#
# Output Format:
# Return the result as:
# 1. Issue
# 2. Frequency
# 3. Short explanation

# %% [markdown]
# Zero-Shot Prompting
#
# The model is given a task without any examples.
#
# Example:
#
# Classify the sentiment:
# "The service was excellent."
# One-Shot Prompting
#
# The model is given one example before the actual task.
#
# Example:
#
# Example:
# "The product is amazing." → Positive
#
# Now classify:
# "The service was terrible."
# Few-Shot Prompting
#
# The model is given multiple examples before the actual task.
#
# Example:
#
# "The product is amazing." → Positive
# "The service was terrible." → Negative
# "The food was okay." → Neutral
#
# Now classify:
# "The delivery was very fast."
#
# Simple difference:
#
# Zero-shot → 0 examples
# One-shot  → 1 example
# Few-shot  → Multiple examples

# %%
pip install langchain_google_genai
# Out:
# Requirement already satisfied: langchain_google_genai in /usr/local/lib/python3.13/dist-packages (4.4.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain_google_genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=2.20.0 in /usr/local/lib/python3.13/dist-packages (from langchain_google_genai) (2.22.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from langchain_google_genai) (1.6.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langchain_google_genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain_google_genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (2.57.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain_google_genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain_google_genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain_google_genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain_google_genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain_google_genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain_google_genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.4.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain_google_genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain_google_genai) (3.0)

# %%
pip install langchian_core
# Out:
# ERROR: Could not find a version that satisfies the requirement langchian_core (from versions: none)
# ERROR: No matching distribution found for langchian_core

# %% [markdown]
# This is old method in which we give instruction in one single prompt.

# %%
from langchain_core.prompts import PromptTemplate
# from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from google.colab import userdata
GEMINI_API_KEY=userdata.get('GEMINI_API_KEY')

# %%
prompt = PromptTemplate.from_template(
    """
You are an AI instructor.

Explain {topic} to {audience}.

Requirements:
- Use simple English
- Include one practical example
- Keep the answer under {word_limit} words
"""
)

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite",
    api_key=GEMINI_API_KEY
)

# %%
chain = prompt | model
# we connect the prompt to model

# %%
response = chain.invoke(
    {
        "topic": "Vector Database",
        "audience": "beginner developers",
        "word_limit": 200
    }
)
# Out:
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.

# %%
print(response.content[0]["text"])
# Out:
# To understand a **Vector Database**, first, you need to understand how computers see data.
#
# ### 1. The Core Concept: Vectors
# Standard databases (like MySQL) store data in rows and columns. They are great at finding exact matches, like "Find the user with ID 101."
#
# But computers are bad at understanding "meaning." They don't naturally know that "puppy" and "dog" are similar.
#
# To fix this, we turn data (text, images, audio) into **Vectors**. A vector is just a long list of numbers (coordinates) that represents the "meaning" of the data in a multi-dimensional space.
# *   **Example:** If we have a 3D space, "Dog" might be at coordinate `[1, 0, 0]` and "Puppy" might be at `[1, 0, 1]`. Because these numbers are close together, the computer knows they are related.
#
# ### 2. What is a Vector Database?
# A **Vector Database** is a specialized database designed to store these lists of numbers. Its superpower is **Similarity Search**.
#
# Instead of asking, "Find rows where the name is X," you ask, "Find things that are *mathematically similar* to this input."
#
# ### 3. A Practical Example: A Recommendation System
# Imagine you are building a music app. You want to recommend songs similar to "Bohemian Rhapsody."
#
# 1.  **Preparation:** You run all your songs through an AI model (like an Embedding model). It turns every song into a list of numbers representing the "vibe," rhythm, and genre.
# 2.  **Storage:** You save these lists (vectors) into your **Vector Database**.
# 3.  **The Search:**
#     *   A user clicks "Bohemian Rhapsody."
#     *   The app sends the vector for that song to the database.
#     *   The database performs a **Nearest Neighbor search**. It looks for other vectors that are physically close to that song in its mathematical space.
#     *   It returns: "We found 5 songs that are mathematically similar to your choice."
#
# ### Why do developers use them?
# *   **Search engines:** Finding results based on intent, not just keywords.
# *   **AI Chatbots (LLMs):** They use vector databases to give the AI "long-term memory" by retrieving relevant documents before answering a question (this is called RAG: Retrieval-Augmented Generation).
# *   **Image searching:** Finding photos that look like the one you uploaded.
#
# ### Summary
# *   **Standard Databases:** Good for exact data ("What is the price of this item?").
# *   **Vector Databases:** Good for fuzzy, human-like concepts ("Show me items that feel like this one").
#
# **Popular tools to look into:** Pinecone, Weaviate, Milvus, or ChromaDB.

# %% [markdown]
# This is the newear technique in which we give me instruction in mulitple messages rather than first one.

# %%
from langchain_core.prompts import ChatPromptTemplate
# from langchain_openai import ChatOpenAI

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are an experienced AI instructor. Use simple English."
        ),
        (
            "human",
            "Explain {topic} to {audience}. Include one example."
        )
    ]
)

# %%
# model = ChatOpenAI(model="gpt-5.6")

# %%
chain = prompt | model

# %%
response = chain.invoke(
    {
        "topic": "Vector Database",
        "audience": "beginner developers"
    }
)

# %%
print(response.content[0]['text'])
# Out:
# To explain web development to an advanced developer (someone already proficient in systems architecture, memory management, or low-level computing), we should frame it not as "making websites," but as **distributed systems engineering constrained by a heterogeneous, sandboxed runtime.**
#
# ### The Core Concept
# Web development is essentially the art of building **event-driven, distributed state machines** that operate across an unreliable network.
#
# 1.  **The Runtime:** You are writing code for a sandboxed environment (the browser) that you do not control. You have no direct access to hardware, file systems, or memory addresses.
# 2.  **The Protocol:** Everything relies on stateless HTTP/S. You are constantly bridging the gap between a **stateless transport layer** and a **stateful user experience**.
# 3.  **The Synchronization Problem:** Your primary challenge is the "Sync-Consistency-Latency" trilemma: Keeping the UI (Client State) in sync with the persistent storage (Server/Database State) while managing network jitter and offline availability.
#
# ### The Paradigm Shift
# If you come from a systems background, think of the browser as a **remote virtual machine** that handles rendering and I/O, and the server as your **backend data orchestrator**. The "Web" is simply a complex mechanism to serialize UI state changes into network packets and reconcile them on the other side.
#
# ---
#
# ### Example: Optimistic UI Updates
# In a low-level systems context, you might use a mutex or a transaction log to ensure state consistency. In web development, we use **Optimistic UI** to hide the latency of the network.
#
# **The Workflow:**
# 1.  **Intent:** The user clicks "Like" on a post.
# 2.  **Immediate Mutation:** Instead of waiting for a network round-trip (RRT), you locally update the UI state (incrementing the counter) and commit that to the DOM immediately.
# 3.  **Network Operation:** You fire an asynchronous `fetch()` request to the server.
# 4.  **Reconciliation:**
#     *   **Success:** The server returns 200 OK. Your local state remains as is.
#     *   **Failure:** The server returns 500. You must perform an "undo" operation: revert the local UI state and trigger a side effect (e.g., an error notification).
#
# **Why this is interesting to an advanced developer:**
# You are effectively implementing **distributed eventual consistency** at the application layer. You are managing a shadow state (optimistic) that acts as a placeholder for the eventual "truth" (server response), requiring you to handle rollbacks and race conditions (e.g., if the user clicks "Like" multiple times while the first request is in-flight).
#
# **Summary for the Senior Engineer:** Web development is not about HTML; it’s about managing the **serialization and eventual consistency of UI state over an asynchronous transport layer.**

# %%
response = chain.invoke(
    {
        "topic": "web development",
        "audience": "advanced developers"
    }
)

# %%
print(response.content[0]["text"])
# Out:
# To understand a **Vector Database**, first, you need to understand how computers see data.
#
# ### 1. The Core Concept: Vectors
# Standard databases (like MySQL) store data in rows and columns. They are great at finding exact matches, like "Find the user with ID 101."
#
# But computers are bad at understanding "meaning." They don't naturally know that "puppy" and "dog" are similar.
#
# To fix this, we turn data (text, images, audio) into **Vectors**. A vector is just a long list of numbers (coordinates) that represents the "meaning" of the data in a multi-dimensional space.
# *   **Example:** If we have a 3D space, "Dog" might be at coordinate `[1, 0, 0]` and "Puppy" might be at `[1, 0, 1]`. Because these numbers are close together, the computer knows they are related.
#
# ### 2. What is a Vector Database?
# A **Vector Database** is a specialized database designed to store these lists of numbers. Its superpower is **Similarity Search**.
#
# Instead of asking, "Find rows where the name is X," you ask, "Find things that are *mathematically similar* to this input."
#
# ### 3. A Practical Example: A Recommendation System
# Imagine you are building a music app. You want to recommend songs similar to "Bohemian Rhapsody."
#
# 1.  **Preparation:** You run all your songs through an AI model (like an Embedding model). It turns every song into a list of numbers representing the "vibe," rhythm, and genre.
# 2.  **Storage:** You save these lists (vectors) into your **Vector Database**.
# 3.  **The Search:**
#     *   A user clicks "Bohemian Rhapsody."
#     *   The app sends the vector for that song to the database.
#     *   The database performs a **Nearest Neighbor search**. It looks for other vectors that are physically close to that song in its mathematical space.
#     *   It returns: "We found 5 songs that are mathematically similar to your choice."
#
# ### Why do developers use them?
# *   **Search engines:** Finding results based on intent, not just keywords.
# *   **AI Chatbots (LLMs):** They use vector databases to give the AI "long-term memory" by retrieving relevant documents before answering a question (this is called RAG: Retrieval-Augmented Generation).
# *   **Image searching:** Finding photos that look like the one you uploaded.
#
# ### Summary
# *   **Standard Databases:** Good for exact data ("What is the price of this item?").
# *   **Vector Databases:** Good for fuzzy, human-like concepts ("Show me items that feel like this one").
#
# **Popular tools to look into:** Pinecone, Weaviate, Milvus, or ChromaDB.

# %% [markdown]
# PromptTemplate
# → Creates a single text prompt
#
# ChatPromptTemplate
# → Creates structured chat messages with roles
#    such as system, human, and assistant

# %%
from langchain_core.prompts import PromptTemplate

# %%
template = """
You are an AI instructor.

Explain {{ topic }} to {{ audience }}.

{% if include_example %}
Include one practical example.
{% endif %}

{% if level == "beginner" %}
Use very simple English and avoid complex terminology.
{% elif level == "advanced" %}
Include technical details and architecture.
{% else %}
Use moderate technical depth.
{% endif %}
"""

# %% [markdown]
# "topic": "RAG",
# "audience": "Python developers",
# "include_example": True,
# "level": "beginner"
#
# You are an AI instructor.
# Explain RAG to Python developers.
# Include one practical example.
# Use very simple English and avoid complex terminology.

# %%
prompt = PromptTemplate.from_template(
    template,
    template_format="jinja2"
)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['audience', 'include_example', 'level', 'topic'], input_types={}, partial_variables={}, template='\nYou are an AI instructor.\n\nExplain {{ topic }} to {{ audience }}.\n\n{% if include_example %}\nInclude one practical example.\n{% endif %}\n\n{% if level == "beginner" %}\nUse very simple English and avoid complex terminology.\n{% elif level == "advanced" %}\nInclude technical details and architecture.\n{% else %}\nUse moderate technical depth.\n{% endif %}\n', template_format='jinja2')

# %% [markdown]
# PromptTemplate(input_variables=['audience', 'include_example', 'level', 'topic'], input_types={}, partial_variables={}, template='\nYou are an AI instructor.\n\nExplain {{ topic }} to {{ audience }}.\n\n{% if include_example %}\nInclude one practical example.\n{% endif %}\n\n{% if level == "beginner" %}\nUse very simple English and avoid complex terminology.\n{% elif level == "advanced" %}\nInclude technical details and architecture.\n{% else %}\nUse moderate technical depth.\n{% endif %}\n', template_format='jinja2')

# %%
formatted_prompt = prompt.invoke(
    {
        "topic": "RAG",
        "audience": "Python developers",
        "include_example": True,
        "level": "beginner"
    }
)

# %%
print(formatted_prompt.to_string())
# Out:
# You are an AI instructor.
#
# Explain RAG to Python developers.
#
#
# Include one practical example.
#
#
#
# Use very simple English and avoid complex terminology.

# %%
from langchain_core.prompts import PromptTemplate

# %%
template = """
You are a customer support assistant.

Customer Query:
{{ query }}

{% if user_type == "premium" %}
Provide a detailed response and mention priority support.
{% else %}
Provide a concise response.
{% endif %}
"""

# %% [markdown]
# You are a customer support assistant.
#
# Customer Query:
# My payment failed.
#
#
# Provide a detailed response and mention priority support.

# %%
prompt = PromptTemplate.from_template(
    template,
    template_format="jinja2"
)

# %%
describe_problem = input("Enter customer query: ")
difficulty_level = input("Enter difficulty level (easy/medium/hard): ")
# Out:
# Enter customer query: what is prompt engineering
# Enter difficulty level (easy/medium/hard): easy

# %%
result = prompt.invoke(
    {
        "query": describe_problem,
        "user_type": difficulty_level
    }
)

# %%
print(result.to_string())
# Out:
# You are a customer support assistant.
#
# Customer Query:
# what is prompt engineering
#
#
# Provide a concise response.

# %% [markdown]
# ### Jinja prompting allows us to dynamically change parts of a prompt using variables, conditions, and loops.

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
You are an AI instructor.

{% if level == "beginner" %}
Use very simple English and avoid complex terminology.
{% elif level == "advanced" %}
Include technical details and architecture.
{% else %}
Use moderate technical depth.
{% endif %}
"""
        ),
        (
            "human",
            """
Explain {{ topic }} to {{ audience }}.

{% if include_example %}
Include one practical example.
{% endif %}
"""
        )
    ],
    template_format="jinja2"
)

# %%
formatted_prompt = prompt.invoke(
    {
        "topic": "RAG",
        "audience": "Python developers",
        "include_example": True,
        "level": "beginner"
    }
)

# %%
user_question="explain me about the RAG?"
regular_expression
llm_capility-->prmpt--user_questio-->parse--->response

# %%
for message in formatted_prompt.to_messages():
    print(message.type.upper())
    print(message.content)
# Out:
# SYSTEM
#
# You are an AI instructor.
#
#
# Use very simple English and avoid complex terminology.
#
# HUMAN
#
# Explain RAG to Python developers.
#
#
# Include one practical example.

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
You are an enterprise AI assistant.

Follow these rules:

{% for rule in rules %}
- {{ rule }}
{% endfor %}
"""
        ),
        (
            "human",
            """
Question:
{{ question }}

{% if output_format == "json" %}
Return the response in JSON format.
{% else %}
Return the response in Markdown.
{% endif %}
"""
        )
    ],
    template_format="jinja2"
)

# %%
result = prompt.invoke(
    {
        "rules": [
            "Do not fabricate information",
            "Keep the answer concise",
            "Use only the supplied context"
        ],
        "question": "What is RAG?",
        "output_format": "json"
    }
)

# %%
print(result.to_messages())
# Out:
# [SystemMessage(content='\nYou are an enterprise AI assistant.\n\nFollow these rules:\n\n\n- Do not fabricate information\n\n- Keep the answer concise\n\n- Use only the supplied context\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='\nQuestion:\nWhat is RAG?\n\n\nReturn the response in JSON format.\n', additional_kwargs={}, response_metadata={})]

# %%
for message in result.to_messages():
    print(message.type, ":", message.content)
# Out:
# system :
# You are an enterprise AI assistant.
#
# Follow these rules:
#
#
# - Do not fabricate information
#
# - Keep the answer concise
#
# - Use only the supplied context
#
# human :
# Question:
# What is RAG?
#
#
# Return the response in JSON format.

# %% [markdown]
# PromptTemplate + Jinja
# → Dynamic single-text prompt
#
# ChatPromptTemplate + Jinja
# → Dynamic role-based chat prompt
#    + variables
#    + if/else
#    + loops

# %%
pip json
# Out:
# ERROR: unknown command "json"

# %% [markdown]
# Now we can read the prompt that is called prompt management.

# %%
import json

with open("/content/prompts.json", "r", encoding="utf-8") as file:
    prompts = json.load(file)

# %%
prompts
# Out:
# {'rag_prompt': 'Answer the question using only the provided context.\n\nContext: {context}\n\nQuestion: {question}',
#  'summary_prompt': 'Summarize the following text in 3 bullet points.\n\nText: {text}',
#  'classification_prompt': 'Classify the following text as Positive, Negative, or Neutral.\n\nText: {text}',
#  'code_review_prompt': 'Review the following Python code and identify any bugs.\n\nCode: {code}'}

# %%
prompt = prompts["rag_prompt"]

# %%
prompt
# Out:
# 'Answer the question using only the provided context.\n\nContext: {context}\n\nQuestion: {question}'

# %%
final_prompt = prompt.format(
    context="Employees receive 24 paid leaves every year.",
    question="How many paid leaves do employees receive?"
)

# %%
final_prompt
# Out:
# 'Answer the question using only the provided context.\n\nContext: Employees receive 24 paid leaves every year.\n\nQuestion: How many paid leaves do employees receive?'

# %%
print(final_prompt)
# Out:
# Answer the question using only the provided context.
#
# Context: Employees receive 24 paid leaves every year.
#
# Question: How many paid leaves do employees receive?

# %%
import json
from langchain_core.prompts import ChatPromptTemplate

# %%
def load_prompt(prompt_name):

    with open("/content/prompt.json", "r", encoding="utf-8") as file:
        prompts = json.load(file)

    if prompt_name not in prompts:
        raise ValueError(
            f"Prompt '{prompt_name}' not found."
        )

    config = prompts[prompt_name]

    messages = [
        (message["role"], message["template"])
        for message in config["messages"]
    ]

    prompt = ChatPromptTemplate.from_messages(
        messages,
        template_format=config["template_format"]
    )

    return prompt

# %%
prompt = load_prompt("rag_prompt")

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template="You are a RAG assistant. Answer only from the provided context. If the answer is not available, say 'I do not have enough information.'", template_format='jinja2'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='Context:\n{{ context }}\n\nQuestion:\n{{ question }}', template_format='jinja2'), additional_kwargs={})])

# %%
result = prompt.invoke(
    {
        "context": """
        Employees receive 24 paid leaves every year.
        Maximum 10 unused leaves can be carried forward.
        """,

        "question": "How many paid leaves are available?"
    }
)

# %%
for message in result.to_messages():
    print(message.type.upper())
    print(message.content)
# Out:
# SYSTEM
# You are a RAG assistant. Answer only from the provided context. If the answer is not available, say 'I do not have enough information.'
# HUMAN
# Context:
#
#         Employees receive 24 paid leaves every year.
#         Maximum 10 unused leaves can be carried forward.
#
#
# Question:
# How many paid leaves are available?

# %%
prompt = load_prompt("summarization_prompt")

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['num_points', 'text'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a professional text summarizer.', template_format='jinja2'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['num_points', 'text'], input_types={}, partial_variables={}, template='Summarize the following text in {{ num_points }} bullet points:\n\n{{ text }}', template_format='jinja2'), additional_kwargs={})])

# %%
result = prompt.invoke(
    {
        "num_points": 3,
        "text": "How many paid leaves are available?"
    }
)

# %%
for message in result.to_messages():
    print(message.type.upper())
    print(message.content)
# Out:
# SYSTEM
# You are a RAG assistant. Answer only from the provided context. If the answer is not available, say 'I do not have enough information.'
# HUMAN
# Context:
#
#         Employees receive 24 paid leaves every year.
#         Maximum 10 unused leaves can be carried forward.
#
#
# Question:
# How many paid leaves are available?

# %%
# from langchain_openai import ChatOpenAI

# model = ChatOpenAI(
#     model="gpt-5.6"
# )

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite",
    api_key=GEMINI_API_KEY
)

prompt = load_prompt(
    "rag_prompt"
)

chain = prompt | model

response = chain.invoke(
    {
        "context": """
        Employees receive 24 paid leaves annually.
        """,

        "question":
        "How many paid leaves do employees receive?"
    }
)

print(response.content)
# Out:
# [{'type': 'text', 'text': 'Employees receive 24 paid leaves annually.', 'extras': {'signature': 'EnEKbwERTTIPQ2JTlxR3Ke5hvhPLvWF+bh40x8a6Bp1qq2JdHC9qnubn30+QigFDD7l1oF9MbJnTyMA9cKcTkYqNUQtlRGOB+WIyCZTFdxpHgD07VCDfBQFuvmMjJG2ZqlhlXYVI1Rf+g3B94GrF0paF9w=='}}]

# %% [markdown]
# prompts.json
#      │
#      ├── rag_prompt
#      ├── summarization_prompt
#      ├── classification_prompt
#      └── code_review_prompt
#               ↓
#         load_prompt()
#               ↓
#      ChatPromptTemplate
#               ↓
#              LLM

# %%
load_prompt("rag_prompt")

load_prompt("summarization_prompt")

load_prompt("classification_prompt")

load_prompt("code_review_prompt")
# Out:
# ChatPromptTemplate(input_variables=['code'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are a senior Python code reviewer.', template_format='jinja2'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['code'], input_types={}, partial_variables={}, template='Review the following Python code for:\n- Bugs\n- Security issues\n- Performance issues\n- Readability\n\nCode:\n{{ code }}', template_format='jinja2'), additional_kwargs={})])

# %%
from langsmith import Client
from langchain_core.prompts import ChatPromptTemplate

client = Client()

prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple English."
)

client.push_prompt(
    "ai-teaching-prompt",
    object=prompt
)

# %%
from langsmith import Client

client = Client()

prompt = client.pull_prompt(
    "ai-teaching-prompt"
)

result = prompt.invoke({
    "topic": "RAG"
})

print(result)
